# %%
# !pip install torch
# !pip install torchvision
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# !pip install scikit-learn

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import scipy
from torch.autograd import Variable

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# ### Setting Seed

# %%
seed = 10
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Obtaining our datasets and dataloaders

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}


train_dataset = datasets.Flowers102(root='./train', split = "train", transform=data_transforms["train"], download = True)
val_dataset = datasets.Flowers102(root='./train', split = "val", transform=data_transforms["val"], download = False)
test_dataset = datasets.Flowers102(root='./train', split = "test", transform=data_transforms["test"], download = False)


train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=4, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=4,num_workers=2 )


image_datasets = {
    'train': train_dataset,
    'val': val_dataset,
    'test': test_dataset
}


dataloaders = {
    "train": train_loader,
    "val": val_loader,
    "test": test_loader,
}

dataset_sizes = {
        x: len(dataloaders[x].dataset)
        for x in list(image_datasets.keys())
    }


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Downloading https://thor.robots.ox.ac.uk/flowers/102/102flowers.tgz to train\flowers-102\102flowers.tgz
# 100%|██████████| 344862509/344862509 [01:56<00:00, 2951910.16it/s]
# Extracting train\flowers-102\102flowers.tgz to train\flowers-102
# Downloading https://thor.robots.ox.ac.uk/flowers/102/imagelabels.mat to train\flowers-102\imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 470617.03it/s]
# Downloading https://thor.robots.ox.ac.uk/flowers/102/setid.mat to train\flowers-102\setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 15108969.64it/s]

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
dataset_sizes
# Out:
# {'train': 1020, 'val': 1020, 'test': 6149}

# %% [markdown]
# ### Function to visualise images

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)


imshow(out, title = classes)

# %% [markdown]
# ### Function to test model on validation set

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                # Changed classes to labels so it corresponds to the labels from dataloader['val']
                ax.set_title(f'predicted: {preds[j]} vs true: {labels[j]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ### General function to train the model

# %%
import torch
import time

def train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, num_epochs=25):
    since = time.time()
    
    # Store training and validation loss/accuracy for analysis
    train_loss, train_acc = [], []
    val_loss, val_acc = [], []

    # Dynamically set device: Use GPU if available, otherwise use CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    model = model.to(device)

    best_acc = 0.0  # Track the best validation accuracy

    for epoch in range(num_epochs):
        print(f'Epoch {epoch + 1}/{num_epochs}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluation mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloaders[phase]:
                # Move inputs and labels to the selected device (CPU or GPU)
                inputs, labels = inputs.to(device), labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward pass
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Accumulate loss and correct predictions
                running_loss += loss.item() * inputs.size(0)
                running_corrects += (preds == labels).sum().item()

            # Step the scheduler only after each epoch during training
            if phase == 'train':
                scheduler.step()

            # Calculate epoch loss and accuracy
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Store metrics for plotting
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)

            # Update best accuracy (for monitoring purposes)
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc

        print()  # New line for readability between epochs

    # Print total training time
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best validation accuracy: {best_acc:.4f}\n')

    return model, train_loss, train_acc, val_loss, val_acc

# %% [markdown]
# ### Function to plot train & val accuracy/loss

# %%
def plot_graph(no_epoch, train, val, title):
    plt.figure()
    plt.plot(range(no_epoch), train, label='train')
    plt.plot(range(no_epoch), val, label='val')
    if "Accuracy" in title:
        plt.ylabel("Accuracy")
    elif "Loss" in title:
        plt.ylabel("Loss")
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# ### Transfer learning with no freezing (transformer vit_b_16)

# %%
model_path = './model_checkpoints/transformer_vit_b_16_unfreeze_GPU.pt'

check_file = os.path.exists(model_path)
if check_file:
    print(f"Loading model from checkpoint")
    loaded_transformer = torch.load(model_path)
    
else:
    print(f"Model checkpoint does not exist.\nDownloading new model...")
    model_conv = torchvision.models.vit_b_16(weights='IMAGENET1K_V1')

    num_ftrs = model_conv.heads.head.in_features
    model_conv.heads.head = nn.Linear(num_ftrs, 102)
# Out:
# Model checkpoint does not exist.
# Downloading new model...

# %%
print(model_conv)
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (head): Linear(in_features=768, out_features=102, bias=True)
#   )
# )

# %%
num_epochs = 40

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_conv = optim.SGD(model_conv.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=50, gamma=0.1)

# %%
model_conv, train_loss, train_acc, val_loss, val_acc = train_model(model_conv, criterion, optimizer_conv,exp_lr_scheduler, dataloaders, dataset_sizes, num_epochs=num_epochs)
# Out:
# Using device: cuda
# Epoch 1/40
# ----------
# C:\Users\Arnav\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# train Loss: 4.6226 Acc: 0.0235
# val Loss: 4.3173 Acc: 0.0392
#
# Epoch 2/40
# ----------
# train Loss: 3.9796 Acc: 0.0843
# val Loss: 3.5475 Acc: 0.1588
#
# Epoch 3/40
# ----------
# train Loss: 3.3374 Acc: 0.1696
# val Loss: 3.0545 Acc: 0.2559
#
# Epoch 4/40
# ----------
# train Loss: 2.8967 Acc: 0.2520
# val Loss: 2.9018 Acc: 0.2559
#
# Epoch 5/40
# ----------
# train Loss: 2.4823 Acc: 0.3618
# val Loss: 2.5951 Acc: 0.3490
#
# Epoch 6/40
# ----------
# train Loss: 2.1685 Acc: 0.4147
# val Loss: 2.3695 Acc: 0.3706
#
# Epoch 7/40
# ----------
# train Loss: 1.7904 Acc: 0.5402
# val Loss: 2.3599 Acc: 0.3941
#
# Epoch 8/40
# ----------
# train Loss: 1.6393 Acc: 0.5431
# val Loss: 2.1173 Acc: 0.4647
#
# Epoch 9/40
# ----------
# train Loss: 1.3860 Acc: 0.6235
# val Loss: 2.0407 Acc: 0.4804
#
# Epoch 10/40
# ----------
# train Loss: 1.2615 Acc: 0.6569
# val Loss: 2.0762 Acc: 0.4647
#
# Epoch 11/40
# ----------
# train Loss: 1.0090 Acc: 0.7304
# val Loss: 2.0838 Acc: 0.4912
#
# Epoch 12/40
# ----------
# train Loss: 0.8892 Acc: 0.7608
# val Loss: 1.9309 Acc: 0.5235
#
# Epoch 13/40
# ----------
# train Loss: 0.7512 Acc: 0.8127
# val Loss: 1.9047 Acc: 0.5147
#
# Epoch 14/40
# ----------
# train Loss: 0.7623 Acc: 0.7931
# val Loss: 1.9091 Acc: 0.5314
#
# Epoch 15/40
# ----------
# train Loss: 0.5364 Acc: 0.8578
# val Loss: 1.8243 Acc: 0.5510
#
# Epoch 16/40
# ----------
# train Loss: 0.6027 Acc: 0.8529
# val Loss: 1.8014 Acc: 0.5627
#
# Epoch 17/40
# ----------
# train Loss: 0.4780 Acc: 0.8804
# val Loss: 1.8441 Acc: 0.5578
#
# Epoch 18/40
# ----------
# train Loss: 0.4392 Acc: 0.8931
# val Loss: 1.7951 Acc: 0.5696
#
# Epoch 19/40
# ----------
# train Loss: 0.4140 Acc: 0.8980
# val Loss: 1.8778 Acc: 0.5647
#
# Epoch 20/40
# ----------
# train Loss: 0.4170 Acc: 0.8961
# val Loss: 1.8060 Acc: 0.5706
#
# Epoch 21/40
# ----------
# train Loss: 0.2750 Acc: 0.9373
# val Loss: 1.7743 Acc: 0.5941
#
# Epoch 22/40
# ----------
# train Loss: 0.3266 Acc: 0.9118
# val Loss: 1.8839 Acc: 0.5735
#
# Epoch 23/40
# ----------
# train Loss: 0.3522 Acc: 0.9069
# val Loss: 1.8196 Acc: 0.5667
#
# Epoch 24/40
# ----------
# train Loss: 0.2978 Acc: 0.9225
# val Loss: 1.8445 Acc: 0.5765
#
# Epoch 25/40
# ----------
# train Loss: 0.3107 Acc: 0.9225
# val Loss: 1.7686 Acc: 0.5882
#
# Epoch 26/40
# ----------
# train Loss: 0.2464 Acc: 0.9333
# val Loss: 1.8719 Acc: 0.5598
#
# Epoch 27/40
# ----------
# train Loss: 0.2185 Acc: 0.9529
# val Loss: 1.7153 Acc: 0.6000
#
# Epoch 28/40
# ----------
# train Loss: 0.2199 Acc: 0.9500
# val Loss: 1.7281 Acc: 0.5990
#
# Epoch 29/40
# ----------
# train Loss: 0.2596 Acc: 0.9275
# val Loss: 1.7491 Acc: 0.5882
#
# Epoch 30/40
# ----------
# train Loss: 0.2580 Acc: 0.9392
# val Loss: 1.7635 Acc: 0.5833
#
# Epoch 31/40
# ----------
# train Loss: 0.1596 Acc: 0.9618
# val Loss: 1.7623 Acc: 0.6078
#
# Epoch 32/40
# ----------
# train Loss: 0.1651 Acc: 0.9559
# val Loss: 1.7843 Acc: 0.6010
#
# Epoch 33/40
# ----------
# train Loss: 0.1835 Acc: 0.9598
# val Loss: 1.7438 Acc: 0.6137
#
# Epoch 34/40
# ----------
# train Loss: 0.1930 Acc: 0.9461
# val Loss: 1.7365 Acc: 0.5971
#
# Epoch 35/40
# ----------
# train Loss: 0.1625 Acc: 0.9618
# val Loss: 1.7144 Acc: 0.6137
#
# Epoch 36/40
# ----------
# train Loss: 0.2072 Acc: 0.9500
# val Loss: 1.7870 Acc: 0.5990
#
# Epoch 37/40
# ----------
# train Loss: 0.1954 Acc: 0.9529
# val Loss: 1.7338 Acc: 0.6069
#
# Epoch 38/40
# ----------
# train Loss: 0.1751 Acc: 0.9529
# val Loss: 1.8263 Acc: 0.5873
#
# Epoch 39/40
# ----------
# train Loss: 0.2070 Acc: 0.9461
# val Loss: 1.8475 Acc: 0.5863
#
# Epoch 40/40
# ----------
# train Loss: 0.1365 Acc: 0.9676
# val Loss: 1.7998 Acc: 0.6118
#
# Training complete in 24m 16s
# Best validation accuracy: 0.6137

# %%
plot_graph(num_epochs, train_acc, val_acc, "Epoch vs Accuracy")

# %%
plot_graph(num_epochs, train_loss, val_loss, "Epoch vs Loss")

# %% [markdown]
# ### Visualising loaded model on validation set

# %%
visualize_model(model_conv)

# %% [markdown]
# ### Testing on test set

# %%
def test(model):
    was_training = model.training
    model.eval()
    # fig = plt.figure()
    size = len(dataloaders['test'].dataset)
    no_batches = len(dataloaders['test'])
    test_loss, correct = 0, 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            preds = preds.to(device)
            
            test_loss += criterion(outputs, labels).item() * inputs.size(0)
            correct += torch.sum(preds == labels.data)
            if i % 20 == 0:
                print(f'Predicted: {preds[0]} | True: {labels[0]}')
  
    test_loss /= size
    correct = correct.double() / size
    model.train(mode=was_training)
    return test_loss, correct

# %%
test_loss, test_acc = test(model_conv)
# Out:
# Predicted: 54 | True: 0
# Predicted: 20 | True: 3
# Predicted: 70 | True: 4
# Predicted: 7 | True: 7
# Predicted: 9 | True: 9
# Predicted: 48 | True: 11
# Predicted: 40 | True: 12
# Predicted: 15 | True: 15
# Predicted: 16 | True: 16
# Predicted: 8 | True: 18
# Predicted: 78 | True: 21
# Predicted: 22 | True: 22
# Predicted: 26 | True: 26
# Predicted: 38 | True: 28
# Predicted: 29 | True: 29
# Predicted: 32 | True: 32
# Predicted: 71 | True: 35
# Predicted: 36 | True: 36
# Predicted: 37 | True: 37
# Predicted: 30 | True: 40
# Predicted: 53 | True: 40
# Predicted: 30 | True: 42
# Predicted: 98 | True: 42
# Predicted: 67 | True: 44
# Predicted: 45 | True: 45
# Predicted: 45 | True: 45
# Predicted: 46 | True: 46
# Predicted: 48 | True: 48
# Predicted: 83 | True: 50
# Predicted: 50 | True: 50
# Predicted: 8 | True: 50
# Predicted: 51 | True: 51
# Predicted: 99 | True: 52
# Predicted: 53 | True: 53
# Predicted: 55 | True: 55
# Predicted: 56 | True: 56
# Predicted: 57 | True: 57
# Predicted: 58 | True: 58
# Predicted: 59 | True: 59
# Predicted: 0 | True: 61
# Predicted: 64 | True: 64
# Predicted: 64 | True: 64
# Predicted: 67 | True: 67
# Predicted: 48 | True: 69
# Predicted: 43 | True: 71
# Predicted: 63 | True: 72
# Predicted: 80 | True: 72
# Predicted: 20 | True: 72
# Predicted: 98 | True: 73
# Predicted: 6 | True: 74
# Predicted: 61 | True: 74
# Predicted: 39 | True: 75
# Predicted: 76 | True: 76
# Predicted: 76 | True: 76
# Predicted: 78 | True: 76
# Predicted: 80 | True: 77
# Predicted: 96 | True: 79
# Predicted: 75 | True: 80
# Predicted: 80 | True: 80
# Predicted: 27 | True: 81
# Predicted: 82 | True: 82
# Predicted: 100 | True: 82
# Predicted: 10 | True: 83
# Predicted: 85 | True: 85
# Predicted: 82 | True: 87
# Predicted: 93 | True: 87
# Predicted: 52 | True: 88
# Predicted: 4 | True: 88
# Predicted: 20 | True: 89
# Predicted: 91 | True: 91
# Predicted: 30 | True: 93
# Predicted: 93 | True: 93
# Predicted: 94 | True: 94
# Predicted: 1 | True: 95
# Predicted: 96 | True: 96
# Predicted: 97 | True: 97
# Predicted: 99 | True: 99

# %%
print(f"Test Loss: {test_loss}")
print(f"Test Acc: {test_acc}")
# Out:
# Test Loss: 2.123502861464648
# Test Acc: 0.5552122296308343
